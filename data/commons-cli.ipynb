# %% [markdown]
# # uCov case study

# %% [markdown]
# ## Import and functions

# %%
import pandas as pd

# %%
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)

# %%
# 
def unique_uses(ref_suf, comp_suf, cols=["usageKind","usageType","usageFullyQualifiedName"]):
    unique_suf = ref_suf[cols].drop_duplicates().merge(comp_suf[cols].drop_duplicates(), how='left', indicator=True)
    return unique_suf[unique_suf['_merge'] == 'left_only'][cols]

# %% [markdown]
# ## Loading data

# %%
sum = pd.read_csv("commons-cli-1.5.0.SUM.csv", sep="|")

# bug fix for initial ucov versions not adding "Method > VirtualInvocation" when a "Method > Invocation" is found
missing_data = sum[sum["usageKind"] == "SYMBOL_KIND_METHOD"][sum["usageType"] == "SYMBOL_USE_INVOCATION"]
missing_data['usageType'].replace({"SYMBOL_USE_INVOCATION": "SYMBOL_USE_VIRTUAL_INVOCATION"}, inplace=True)
sum = pd.concat([sum, missing_data], ignore_index=True)
sum.drop_duplicates(inplace=True)

sum['qualifiedUse'] = sum['usageKind'] + ' > ' + sum['usageType']
sum.head()
# Out:
# /tmp/ipykernel_5008/653788187.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   missing_data = sum[sum["usageKind"] == "SYMBOL_KIND_METHOD"][sum["usageType"] == "SYMBOL_USE_INVOCATION"]
#            projectId projectType                 projectLocation  \
# 0  commons-cli-1.5.0        MAIN  I:/UCov/Repro/commons-cli/Main
# 1  commons-cli-1.5.0        MAIN  I:/UCov/Repro/commons-cli/Main
# 2  commons-cli-1.5.0        MAIN  I:/UCov/Repro/commons-cli/Main
# 3  commons-cli-1.5.0        MAIN  I:/UCov/Repro/commons-cli/Main
# 4  commons-cli-1.5.0        MAIN  I:/UCov/Repro/commons-cli/Main
#
#                                                       usagePosition  \
# 0     /src/main/java/org/apache/commons/cli/optiongroup.java(75:19)
# 1         /src/main/java/org/apache/commons/cli/options.java(96:20)
# 2  /src/main/java/org/apache/commons/cli/defaultparser.java(128:27)
# 3  /src/main/java/org/apache/commons/cli/helpformatter.java(431:17)
# 4         /src/main/java/org/apache/commons/cli/option.java(778:17)
#
#                                                   usageEndPosition  \
# 0     /src/main/java/org/apache/commons/cli/optiongroup.java(77:5)
# 1         /src/main/java/org/apache/commons/cli/options.java(99:5)
# 2  /src/main/java/org/apache/commons/cli/defaultparser.java(130:5)
# 3  /src/main/java/org/apache/commons/cli/helpformatter.java(437:5)
# 4         /src/main/java/org/apache/commons/cli/option.java(780:5)
#
#                                                                                                                          usageFullyQualifiedName  \
# 0                                                                                               org.apache.commons.cli.OptionGroup.getSelected()
# 1                                                            org.apache.commons.cli.Options.addOption(java.lang.String,boolean,java.lang.String)
# 2                                                                                                 org.apache.commons.cli.DefaultParser.builder()
# 3  org.apache.commons.cli.HelpFormatter.printHelp(int,java.lang.String,java.lang.String,org.apache.commons.cli.Options,java.lang.String,boolean)
# 4                                                                                     org.apache.commons.cli.Option.setArgName(java.lang.String)
#
#             usageKind                     usageType  \
# 0  SYMBOL_KIND_METHOD         SYMBOL_USE_OVERRIDING
# 1  SYMBOL_KIND_METHOD         SYMBOL_USE_INVOCATION
# 2  SYMBOL_KIND_METHOD  SYMBOL_USE_STATIC_INVOCATION
# 3  SYMBOL_KIND_METHOD         SYMBOL_USE_OVERRIDING
# 4  SYMBOL_KIND_METHOD         SYMBOL_USE_INVOCATION
#
#                                         qualifiedUse
# 0         SYMBOL_KIND_METHOD > SYMBOL_USE_OVERRIDING
# 1         SYMBOL_KIND_METHOD > SYMBOL_USE_INVOCATION
# 2  SYMBOL_KIND_METHOD > SYMBOL_USE_STATIC_INVOCATION
# 3         SYMBOL_KIND_METHOD > SYMBOL_USE_OVERRIDING
# 4         SYMBOL_KIND_METHOD > SYMBOL_USE_INVOCATION

# %%
suf = pd.read_csv("commons-cli-1.5.0.SUF.csv", sep="|")

# bug fix for initial ucov versions not adding "Method > VirtualInvocation" when a "Method > Invocation" is found
missing_data = suf[suf["usageKind"] == "SYMBOL_KIND_METHOD"][suf["usageType"] == "SYMBOL_USE_INVOCATION"]
missing_data['usageType'].replace({"SYMBOL_USE_INVOCATION": "SYMBOL_USE_VIRTUAL_INVOCATION"}, inplace=True)
suf = pd.concat([suf, missing_data], ignore_index=True)
suf.drop_duplicates(inplace=True)

suf['qualifiedUse'] = suf['usageKind'] + ' > ' + suf['usageType']
suf['qualifiedSymbol'] = suf['usageFullyQualifiedName'] + ' > ' + suf['usageType']
suf.head()
# Out:
# /tmp/ipykernel_5008/1680720302.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   missing_data = suf[suf["usageKind"] == "SYMBOL_KIND_METHOD"][suf["usageType"] == "SYMBOL_USE_INVOCATION"]
#            projectId projectType                  projectLocation  \
# 0  commons-cli-1.5.0        TEST  I:/UCov/Repro/commons-cli/Tests
# 1  commons-cli-1.5.0        TEST  I:/UCov/Repro/commons-cli/Tests
# 2  commons-cli-1.5.0        TEST  I:/UCov/Repro/commons-cli/Tests
# 3  commons-cli-1.5.0        TEST  I:/UCov/Repro/commons-cli/Tests
# 4  commons-cli-1.5.0        TEST  I:/UCov/Repro/commons-cli/Tests
#
#                                                         usagePosition  \
# 0  /src/test/java/org/apache/commons/cli/applicationtest.java(100:13)
# 1  /src/test/java/org/apache/commons/cli/applicationtest.java(100:13)
# 2  /src/test/java/org/apache/commons/cli/applicationtest.java(100:13)
# 3  /src/test/java/org/apache/commons/cli/applicationtest.java(100:13)
# 4   /src/test/java/org/apache/commons/cli/applicationtest.java(104:9)
#
#                                                      usageEndPosition  \
# 0  /src/test/java/org/apache/commons/cli/applicationtest.java(100:39)
# 1  /src/test/java/org/apache/commons/cli/applicationtest.java(101:53)
# 2  /src/test/java/org/apache/commons/cli/applicationtest.java(102:36)
# 3  /src/test/java/org/apache/commons/cli/applicationtest.java(103:28)
# 4  /src/test/java/org/apache/commons/cli/applicationtest.java(108:30)
#
#                                                    usageFullyQualifiedName  \
# 0                     org.apache.commons.cli.OptionBuilder.hasArg(boolean)
# 1   org.apache.commons.cli.OptionBuilder.withDescription(java.lang.String)
# 2       org.apache.commons.cli.OptionBuilder.withLongOpt(java.lang.String)
# 3                        org.apache.commons.cli.OptionBuilder.create(char)
# 4  org.apache.commons.cli.Options.addOption(org.apache.commons.cli.Option)
#
#             usageKind                     usageType  \
# 0  SYMBOL_KIND_METHOD  SYMBOL_USE_STATIC_INVOCATION
# 1  SYMBOL_KIND_METHOD  SYMBOL_USE_STATIC_INVOCATION
# 2  SYMBOL_KIND_METHOD  SYMBOL_USE_STATIC_INVOCATION
# 3  SYMBOL_KIND_METHOD  SYMBOL_USE_STATIC_INVOCATION
# 4  SYMBOL_KIND_METHOD         SYMBOL_USE_INVOCATION
#
#                                         qualifiedUse  \
# 0  SYMBOL_KIND_METHOD > SYMBOL_USE_STATIC_INVOCATION
# 1  SYMBOL_KIND_METHOD > SYMBOL_USE_STATIC_INVOCATION
# 2  SYMBOL_KIND_METHOD > SYMBOL_USE_STATIC_INVOCATION
# 3  SYMBOL_KIND_METHOD > SYMBOL_USE_STATIC_INVOCATION
# 4         SYMBOL_KIND_METHOD > SYMBOL_USE_INVOCATION
#
#                                                                                          qualifiedSymbol
# 0                    org.apache.commons.cli.OptionBuilder.hasArg(boolean) > SYMBOL_USE_STATIC_INVOCATION
# 1  org.apache.commons.cli.OptionBuilder.withDescription(java.lang.String) > SYMBOL_USE_STATIC_INVOCATION
# 2      org.apache.commons.cli.OptionBuilder.withLongOpt(java.lang.String) > SYMBOL_USE_STATIC_INVOCATION
# 3                       org.apache.commons.cli.OptionBuilder.create(char) > SYMBOL_USE_STATIC_INVOCATION
# 4        org.apache.commons.cli.Options.addOption(org.apache.commons.cli.Option) > SYMBOL_USE_INVOCATION

# %%
suf_test = suf[suf["projectType"] == "TEST"]
suf_sample = suf[suf["projectType"] == "SAMPLE"]
suf_client = suf[suf["projectType"] == "CLIENT"]

# %% [markdown]
# ## Number of unique API interactions & unique API symbols

# %%
print(len(sum))
print(len(sum["usageFullyQualifiedName"].unique()))
# Out:
# 755
# 291

# %% [markdown]
# ## Number of API symbols & interactions used in SUFs

# %%
suf_symbols = suf["usageFullyQualifiedName"].unique()
suf_uses_unique = suf["qualifiedSymbol"].unique()
suf_client_symbols = suf_client["usageFullyQualifiedName"].unique()
suf_client_uses_unique = suf_client["qualifiedSymbol"].unique()
suf_test_symbols = suf_test["usageFullyQualifiedName"].unique()
suf_test_uses_unique = suf_test["qualifiedSymbol"].unique()
suf_sample_symbols = suf_sample["usageFullyQualifiedName"].unique()
suf_sample_uses_unique = suf_sample["qualifiedSymbol"].unique()
print(f'All: {len(suf_symbols)} used, {len(suf)} uses, {len(suf_uses_unique)} unique.')
print(f'Clients: {len(suf_client_symbols)} used, {len(suf_client)} uses, {len(suf_client_uses_unique)} unique.')
print(f'Tests: {len(suf_test_symbols)} used, {len(suf_test)} uses, {len(suf_test_uses_unique)} unique.')
print(f'Samples: {len(suf_sample_symbols)} used, {len(suf_sample)} uses, {len(suf_sample_uses_unique)} unique.')
# Out:
# All: 205 used, 79284 uses, 367 unique.
# Clients: 153 used, 74453 uses, 266 unique.
# Tests: 179 used, 4690 uses, 315 unique.
# Samples: 24 used, 141 uses, 38 unique.

# %% [markdown]
# ## SUM Analysis

# %% [markdown]
# ### Prevalent API interactions in the SUM (~= profile)

# %%
display(sum["qualifiedUse"].value_counts(normalize=True).to_frame().style.bar())
# Out:
# <style type="text/css">
# #T_f6b39_row0_col0, #T_f6b39_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_f6b39_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 81.6%, transparent 81.6%);
# }
# #T_f6b39_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 17.5%, transparent 17.5%);
# }
# #T_f6b39_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 17.0%, transparent 17.0%);
# }
# #T_f6b39_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 12.6%, transparent 12.6%);
# }
# #T_f6b39_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 11.2%, transparent 11.2%);
# }
# #T_f6b39_row7_col0, #T_f6b39_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 8.7%, transparent 8.7%);
# }
# #T_f6b39_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 8.3%, transparent 8.3%);
# }
# #T_f6b39_row10_col0, #T_f6b39_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.5%, transparent 0.5%);
# }
# </style>
# <table id="T_f6b39">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f6b39_level0_col0" class="col_heading level0 col0" >qualifiedUse</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f6b39_level0_row0" class="row_heading level0 row0" >SYMBOL_KIND_METHOD > SYMBOL_USE_OVERRIDING</th>
#       <td id="T_f6b39_row0_col0" class="data row0 col0" >0.272848</td>
#     </tr>
#     <tr>
#       <th id="T_f6b39_level0_row1" class="row_heading level0 row1" >SYMBOL_KIND_METHOD > SYMBOL_USE_VIRTUAL_INVOCATION</th>
#       <td id="T_f6b39_row1_col0" class="data row1 col0" >0.272848</td>
#     </tr>
#     <tr>
#       <th id="T_f6b39_level0_row2" class="row_heading level0 row2" >SYMBOL_KIND_METHOD > SYMBOL_USE_INVOCATION</th>
#       <td id="T_f6b39_row2_col0" class="data row2 col0" >0.222517</td>
#     </tr>
#     <tr>
#       <th id="T_f6b39_level0_row3" class="row_heading level0 row3" >SYMBOL_KIND_FIELD > SYMBOL_USE_INSTANCE_FIELD_READ</th>
#       <td id="T_f6b39_row3_col0" class="data row3 col0" >0.047682</td>
#     </tr>
#     <tr>
#       <th id="T_f6b39_level0_row4" class="row_heading level0 row4" >SYMBOL_KIND_METHOD > SYMBOL_USE_STATIC_INVOCATION</th>
#       <td id="T_f6b39_row4_col0" class="data row4 col0" >0.046358</td>
#     </tr>
#     <tr>
#       <th id="T_f6b39_level0_row5" class="row_heading level0 row5" >SYMBOL_KIND_CONSTRUCTOR > SYMBOL_USE_INVOCATION</th>
#       <td id="T_f6b39_row5_col0" class="data row5 col0" >0.034437</td>
#     </tr>
#     <tr>
#       <th id="T_f6b39_level0_row6" class="row_heading level0 row6" >SYMBOL_KIND_TYPE > SYMBOL_USE_TYPE_REFERENCE</th>
#       <td id="T_f6b39_row6_col0" class="data row6 col0" >0.030464</td>
#     </tr>
#     <tr>
#       <th id="T_f6b39_level0_row7" class="row_heading level0 row7" >SYMBOL_KIND_CLASS > SYMBOL_USE_INHERITANCE</th>
#       <td id="T_f6b39_row7_col0" class="data row7 col0" >0.023841</td>
#     </tr>
#     <tr>
#       <th id="T_f6b39_level0_row8" class="row_heading level0 row8" >SYMBOL_KIND_CLASS > SYMBOL_USE_INSTANTIATION</th>
#       <td id="T_f6b39_row8_col0" class="data row8 col0" >0.023841</td>
#     </tr>
#     <tr>
#       <th id="T_f6b39_level0_row9" class="row_heading level0 row9" >SYMBOL_KIND_FIELD > SYMBOL_USE_INSTANCE_FIELD_WRITE</th>
#       <td id="T_f6b39_row9_col0" class="data row9 col0" >0.022517</td>
#     </tr>
#     <tr>
#       <th id="T_f6b39_level0_row10" class="row_heading level0 row10" >SYMBOL_KIND_INTERFACE > SYMBOL_USE_EXTENSION</th>
#       <td id="T_f6b39_row10_col0" class="data row10 col0" >0.001325</td>
#     </tr>
#     <tr>
#       <th id="T_f6b39_level0_row11" class="row_heading level0 row11" >SYMBOL_KIND_INTERFACE > SYMBOL_USE_IMPLEMENTATION</th>
#       <td id="T_f6b39_row11_col0" class="data row11 col0" >0.001325</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Unused API symbols

# %%
sum_symbols_not_seen = unique_uses(sum, suf, cols=["usageFullyQualifiedName"])
sum_symbols_not_seen_client = unique_uses(sum, suf_client, cols=["usageFullyQualifiedName"])
sum_symbols_not_seen_sample = unique_uses(sum, suf_sample, cols=["usageFullyQualifiedName"])
sum_symbols_not_seen_test = unique_uses(sum, suf_test, cols=["usageFullyQualifiedName"])
sum_uses_not_seen = unique_uses(sum, suf, cols=["qualifiedUse"])

print(f'There are {len(sum_uses_not_seen)} kinds of uses in the SUM unseen in the SUFs.');
display(sum_uses_not_seen.head(n=15))

print("Kinds of uses that are the least covered")
display(unique_uses(sum, suf, cols=["usageFullyQualifiedName", "usageType"]).groupby(["usageType"]).size().sort_values(ascending=False).to_frame().style.bar())

print(f'There are {len(sum_symbols_not_seen)} unused API symbols for all SUFs.');
display(sum_symbols_not_seen.head(n=15))
print(f'There are {len(sum_symbols_not_seen_client)} unused API symbols in clients.');
display(sum_symbols_not_seen_client.head(n=15))
print(f'There are {len(sum_symbols_not_seen_sample)} unused API symbols in samples.');
display(sum_symbols_not_seen_sample.head(n=15))
print(f'There are {len(sum_symbols_not_seen_test)} unused API symbols in tests.');
display(sum_symbols_not_seen_test.head(n=15))
# Out:
# There are 4 kinds of uses in the SUM unseen in the SUFs.
#                                            qualifiedUse
# 7   SYMBOL_KIND_FIELD > SYMBOL_USE_INSTANCE_FIELD_WRITE
# 8    SYMBOL_KIND_FIELD > SYMBOL_USE_INSTANCE_FIELD_READ
# 10         SYMBOL_KIND_INTERFACE > SYMBOL_USE_EXTENSION
# 11    SYMBOL_KIND_INTERFACE > SYMBOL_USE_IMPLEMENTATION
# Kinds of uses that are the least covered
# <style type="text/css">
# #T_2de99_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_2de99_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 29.6%, transparent 29.6%);
# }
# #T_2de99_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 17.7%, transparent 17.7%);
# }
# #T_2de99_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 17.2%, transparent 17.2%);
# }
# #T_2de99_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 8.4%, transparent 8.4%);
# }
# #T_2de99_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 7.4%, transparent 7.4%);
# }
# #T_2de99_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 5.9%, transparent 5.9%);
# }
# #T_2de99_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.5%, transparent 2.5%);
# }
# #T_2de99_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.5%, transparent 1.5%);
# }
# #T_2de99_row9_col0, #T_2de99_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.5%, transparent 0.5%);
# }
# </style>
# <table id="T_2de99">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2de99_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >usageType</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2de99_level0_row0" class="row_heading level0 row0" >SYMBOL_USE_OVERRIDING</th>
#       <td id="T_2de99_row0_col0" class="data row0 col0" >203</td>
#     </tr>
#     <tr>
#       <th id="T_2de99_level0_row1" class="row_heading level0 row1" >SYMBOL_USE_VIRTUAL_INVOCATION</th>
#       <td id="T_2de99_row1_col0" class="data row1 col0" >60</td>
#     </tr>
#     <tr>
#       <th id="T_2de99_level0_row2" class="row_heading level0 row2" >SYMBOL_USE_INSTANCE_FIELD_READ</th>
#       <td id="T_2de99_row2_col0" class="data row2 col0" >36</td>
#     </tr>
#     <tr>
#       <th id="T_2de99_level0_row3" class="row_heading level0 row3" >SYMBOL_USE_INVOCATION</th>
#       <td id="T_2de99_row3_col0" class="data row3 col0" >35</td>
#     </tr>
#     <tr>
#       <th id="T_2de99_level0_row4" class="row_heading level0 row4" >SYMBOL_USE_INSTANCE_FIELD_WRITE</th>
#       <td id="T_2de99_row4_col0" class="data row4 col0" >17</td>
#     </tr>
#     <tr>
#       <th id="T_2de99_level0_row5" class="row_heading level0 row5" >SYMBOL_USE_INHERITANCE</th>
#       <td id="T_2de99_row5_col0" class="data row5 col0" >15</td>
#     </tr>
#     <tr>
#       <th id="T_2de99_level0_row6" class="row_heading level0 row6" >SYMBOL_USE_STATIC_INVOCATION</th>
#       <td id="T_2de99_row6_col0" class="data row6 col0" >12</td>
#     </tr>
#     <tr>
#       <th id="T_2de99_level0_row7" class="row_heading level0 row7" >SYMBOL_USE_INSTANTIATION</th>
#       <td id="T_2de99_row7_col0" class="data row7 col0" >5</td>
#     </tr>
#     <tr>
#       <th id="T_2de99_level0_row8" class="row_heading level0 row8" >SYMBOL_USE_TYPE_REFERENCE</th>
#       <td id="T_2de99_row8_col0" class="data row8 col0" >3</td>
#     </tr>
#     <tr>
#       <th id="T_2de99_level0_row9" class="row_heading level0 row9" >SYMBOL_USE_EXTENSION</th>
#       <td id="T_2de99_row9_col0" class="data row9 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2de99_level0_row10" class="row_heading level0 row10" >SYMBOL_USE_IMPLEMENTATION</th>
#       <td id="T_2de99_row10_col0" class="data row10 col0" >1</td>
#     </tr>
#   </tbody>
# </table>
# There are 86 unused API symbols for all SUFs.
#                                                               usageFullyQualifiedName
# 14                    org.apache.commons.cli.PatternOptionBuilder.getValueClass(char)
# 22                    org.apache.commons.cli.TypeHandler.createDate(java.lang.String)
# 23                               org.apache.commons.cli.Parser.checkRequiredOptions()
# 32                    org.apache.commons.cli.OptionBuilder.withType(java.lang.Object)
# 33                                 org.apache.commons.cli.Parser.getRequiredOptions()
# 34                                         org.apache.commons.cli.Option.hasLongOpt()
# 36                    org.apache.commons.cli.TypeHandler.createFile(java.lang.String)
# 37       org.apache.commons.cli.Options.getOptionGroup(org.apache.commons.cli.Option)
# 49   org.apache.commons.cli.DefaultParser.handleConcatenatedOptions(java.lang.String)
# 55                    org.apache.commons.cli.Options.hasShortOption(java.lang.String)
# 57  org.apache.commons.cli.TypeHandler.createValue(java.lang.String,java.lang.Object)
# 59                              org.apache.commons.cli.HelpFormatter.defaultOptPrefix
# 60                  org.apache.commons.cli.AlreadySelectedException(java.lang.String)
# 62                         org.apache.commons.cli.HelpFormatter.DEFAULT_SYNTAX_PREFIX
# 66                            org.apache.commons.cli.PatternOptionBuilder.FILES_VALUE
# There are 138 unused API symbols in clients.
#                                                                                     usageFullyQualifiedName
# 2                                                            org.apache.commons.cli.DefaultParser.builder()
# 6                          org.apache.commons.cli.TypeHandler.createValue(java.lang.String,java.lang.Class)
# 9                                                      org.apache.commons.cli.DefaultParser$Builder.build()
# 12                   org.apache.commons.cli.CommandLine.getParsedOptionValue(org.apache.commons.cli.Option)
# 14                                          org.apache.commons.cli.PatternOptionBuilder.getValueClass(char)
# 16                                                   org.apache.commons.cli.HelpFormatter.getSyntaxPrefix()
# 17                                  org.apache.commons.cli.HelpFormatter.setLongOptPrefix(java.lang.String)
# 18                                                                  org.apache.commons.cli.Option.hasArgs()
# 20                                                  org.apache.commons.cli.HelpFormatter.createPadding(int)
# 22                                          org.apache.commons.cli.TypeHandler.createDate(java.lang.String)
# 23                                                     org.apache.commons.cli.Parser.checkRequiredOptions()
# 25                              org.apache.commons.cli.CommandLine.addOption(org.apache.commons.cli.Option)
# 27                                                        org.apache.commons.cli.HelpFormatter.getArgName()
# 31  org.apache.commons.cli.HelpFormatter.renderWrappedText(java.lang.StringBuffer,int,int,java.lang.String)
# 32                                          org.apache.commons.cli.OptionBuilder.withType(java.lang.Object)
# There are 267 unused API symbols in samples.
#                                                                                                                           usageFullyQualifiedName
# 0                                                                                                org.apache.commons.cli.OptionGroup.getSelected()
# 2                                                                                                  org.apache.commons.cli.DefaultParser.builder()
# 3   org.apache.commons.cli.HelpFormatter.printHelp(int,java.lang.String,java.lang.String,org.apache.commons.cli.Options,java.lang.String,boolean)
# 4                                                                                      org.apache.commons.cli.Option.setArgName(java.lang.String)
# 5                                                                                                       org.apache.commons.cli.Options.toString()
# 6                                                                org.apache.commons.cli.TypeHandler.createValue(java.lang.String,java.lang.Class)
# 7                                                                                      org.apache.commons.cli.Option$Builder.optionalArg(boolean)
# 8                                                                                                        org.apache.commons.cli.Option.getValue()
# 9                                                                                            org.apache.commons.cli.DefaultParser$Builder.build()
# 10                                                                                       org.apache.commons.cli.OptionBuilder.isRequired(boolean)
# 11                                                                                                             org.apache.commons.cli.BasicParser
# 12                                                         org.apache.commons.cli.CommandLine.getParsedOptionValue(org.apache.commons.cli.Option)
# 14                                                                                org.apache.commons.cli.PatternOptionBuilder.getValueClass(char)
# 15                                                              org.apache.commons.cli.CommandLine.getOptionValues(org.apache.commons.cli.Option)
# 16                                                                                         org.apache.commons.cli.HelpFormatter.getSyntaxPrefix()
# There are 112 unused API symbols in tests.
#                                                                                                                           usageFullyQualifiedName
# 3   org.apache.commons.cli.HelpFormatter.printHelp(int,java.lang.String,java.lang.String,org.apache.commons.cli.Options,java.lang.String,boolean)
# 10                                                                                       org.apache.commons.cli.OptionBuilder.isRequired(boolean)
# 14                                                                                org.apache.commons.cli.PatternOptionBuilder.getValueClass(char)
# 22                                                                                org.apache.commons.cli.TypeHandler.createDate(java.lang.String)
# 23                                                                                           org.apache.commons.cli.Parser.checkRequiredOptions()
# 32                                                                                org.apache.commons.cli.OptionBuilder.withType(java.lang.Object)
# 33                                                                                             org.apache.commons.cli.Parser.getRequiredOptions()
# 34                                                                                                     org.apache.commons.cli.Option.hasLongOpt()
# 36                                                                                org.apache.commons.cli.TypeHandler.createFile(java.lang.String)
# 37                                                                   org.apache.commons.cli.Options.getOptionGroup(org.apache.commons.cli.Option)
# 39                                   org.apache.commons.cli.Options.addRequiredOption(java.lang.String,java.lang.String,boolean,java.lang.String)
# 49                                                               org.apache.commons.cli.DefaultParser.handleConcatenatedOptions(java.lang.String)
# 54                                                                                         org.apache.commons.cli.Option.setType(java.lang.Class)
# 55                                                                                org.apache.commons.cli.Options.hasShortOption(java.lang.String)
# 57                                                              org.apache.commons.cli.TypeHandler.createValue(java.lang.String,java.lang.Object)

# %% [markdown]
# ### Unused API interactions in all SUFs

# %%
sum_not_seen = unique_uses(sum, suf)
print(len(sum_not_seen))
display(sum_not_seen.head(n=15))
# Out:
# 388
#              usageKind                      usageType  \
# 0   SYMBOL_KIND_METHOD          SYMBOL_USE_OVERRIDING
# 3   SYMBOL_KIND_METHOD          SYMBOL_USE_OVERRIDING
# 6   SYMBOL_KIND_METHOD  SYMBOL_USE_VIRTUAL_INVOCATION
# 10  SYMBOL_KIND_METHOD  SYMBOL_USE_VIRTUAL_INVOCATION
# 11   SYMBOL_KIND_CLASS         SYMBOL_USE_INHERITANCE
# 13  SYMBOL_KIND_METHOD          SYMBOL_USE_OVERRIDING
# 14  SYMBOL_KIND_METHOD   SYMBOL_USE_STATIC_INVOCATION
# 17  SYMBOL_KIND_METHOD          SYMBOL_USE_OVERRIDING
# 18  SYMBOL_KIND_METHOD          SYMBOL_USE_OVERRIDING
# 22  SYMBOL_KIND_METHOD          SYMBOL_USE_OVERRIDING
# 23  SYMBOL_KIND_METHOD          SYMBOL_USE_OVERRIDING
# 29  SYMBOL_KIND_METHOD          SYMBOL_USE_OVERRIDING
# 33  SYMBOL_KIND_METHOD          SYMBOL_USE_OVERRIDING
# 34  SYMBOL_KIND_METHOD  SYMBOL_USE_VIRTUAL_INVOCATION
# 35  SYMBOL_KIND_METHOD          SYMBOL_USE_INVOCATION
#
#                                                                                                                           usageFullyQualifiedName
# 0                                                                                                org.apache.commons.cli.OptionGroup.getSelected()
# 3   org.apache.commons.cli.HelpFormatter.printHelp(int,java.lang.String,java.lang.String,org.apache.commons.cli.Options,java.lang.String,boolean)
# 6                                                                org.apache.commons.cli.TypeHandler.createValue(java.lang.String,java.lang.Class)
# 10                                                                                       org.apache.commons.cli.OptionBuilder.isRequired(boolean)
# 11                                                                                                             org.apache.commons.cli.BasicParser
# 13                                                                                   org.apache.commons.cli.Option$Builder.desc(java.lang.String)
# 14                                                                                org.apache.commons.cli.PatternOptionBuilder.getValueClass(char)
# 17                                                                        org.apache.commons.cli.HelpFormatter.setLongOptPrefix(java.lang.String)
# 18                                                                                                        org.apache.commons.cli.Option.hasArgs()
# 22                                                                                org.apache.commons.cli.TypeHandler.createDate(java.lang.String)
# 23                                                                                           org.apache.commons.cli.Parser.checkRequiredOptions()
# 29                                                                                         org.apache.commons.cli.Option$Builder.valueSeparator()
# 33                                                                                org.apache.commons.cli.OptionBuilder.withType(java.lang.Object)
# 34                                                                                             org.apache.commons.cli.Parser.getRequiredOptions()
# 35                                                                                             org.apache.commons.cli.Parser.getRequiredOptions()

# %% [markdown]
# ### Unused API interactions in client

# %%
sum_not_seen = unique_uses(sum, suf_client)
print(len(sum_not_seen))
sum_not_seen.head(n=15)
# Out:
# 489
#              usageKind                      usageType  \
# 0   SYMBOL_KIND_METHOD          SYMBOL_USE_OVERRIDING
# 2   SYMBOL_KIND_METHOD   SYMBOL_USE_STATIC_INVOCATION
# 3   SYMBOL_KIND_METHOD          SYMBOL_USE_OVERRIDING
# 6   SYMBOL_KIND_METHOD  SYMBOL_USE_VIRTUAL_INVOCATION
# 8   SYMBOL_KIND_METHOD          SYMBOL_USE_OVERRIDING
# 9   SYMBOL_KIND_METHOD          SYMBOL_USE_INVOCATION
# 10  SYMBOL_KIND_METHOD  SYMBOL_USE_VIRTUAL_INVOCATION
# 11   SYMBOL_KIND_CLASS         SYMBOL_USE_INHERITANCE
# 12  SYMBOL_KIND_METHOD          SYMBOL_USE_INVOCATION
# 13  SYMBOL_KIND_METHOD          SYMBOL_USE_OVERRIDING
# 14  SYMBOL_KIND_METHOD   SYMBOL_USE_STATIC_INVOCATION
# 16  SYMBOL_KIND_METHOD  SYMBOL_USE_VIRTUAL_INVOCATION
# 17  SYMBOL_KIND_METHOD          SYMBOL_USE_OVERRIDING
# 18  SYMBOL_KIND_METHOD          SYMBOL_USE_OVERRIDING
# 20  SYMBOL_KIND_METHOD          SYMBOL_USE_INVOCATION
#
#                                                                                                                           usageFullyQualifiedName
# 0                                                                                                org.apache.commons.cli.OptionGroup.getSelected()
# 2                                                                                                  org.apache.commons.cli.DefaultParser.builder()
# 3   org.apache.commons.cli.HelpFormatter.printHelp(int,java.lang.String,java.lang.String,org.apache.commons.cli.Options,java.lang.String,boolean)
# 6                                                                org.apache.commons.cli.TypeHandler.createValue(java.lang.String,java.lang.Class)
# 8                                                                                                        org.apache.commons.cli.Option.getValue()
# 9                                                                                            org.apache.commons.cli.DefaultParser$Builder.build()
# 10                                                                                       org.apache.commons.cli.OptionBuilder.isRequired(boolean)
# 11                                                                                                             org.apache.commons.cli.BasicParser
# 12                                                         org.apache.commons.cli.CommandLine.getParsedOptionValue(org.apache.commons.cli.Option)
# 13                                                                                   org.apache.commons.cli.Option$Builder.desc(java.lang.String)
# 14                                                                                org.apache.commons.cli.PatternOptionBuilder.getValueClass(char)
# 16                                                                                         org.apache.commons.cli.HelpFormatter.getSyntaxPrefix()
# 17                                                                        org.apache.commons.cli.HelpFormatter.setLongOptPrefix(java.lang.String)
# 18                                                                                                        org.apache.commons.cli.Option.hasArgs()
# 20                                                                                        org.apache.commons.cli.HelpFormatter.createPadding(int)

# %% [markdown]
# ### Most popular API symbols in all SUFs

# %%
suf.groupby(["usageFullyQualifiedName"]).size().sort_values(ascending=False).to_frame().head(n=15).style.bar()
# Out:
# <style type="text/css">
# #T_80309_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_80309_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 94.9%, transparent 94.9%);
# }
# #T_80309_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 65.0%, transparent 65.0%);
# }
# #T_80309_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 57.9%, transparent 57.9%);
# }
# #T_80309_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 57.8%, transparent 57.8%);
# }
# #T_80309_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_80309_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 44.3%, transparent 44.3%);
# }
# #T_80309_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 41.3%, transparent 41.3%);
# }
# #T_80309_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 33.2%, transparent 33.2%);
# }
# #T_80309_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 25.4%, transparent 25.4%);
# }
# #T_80309_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 22.8%, transparent 22.8%);
# }
# #T_80309_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 17.4%, transparent 17.4%);
# }
# #T_80309_row12_col0, #T_80309_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 15.2%, transparent 15.2%);
# }
# #T_80309_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 13.6%, transparent 13.6%);
# }
# </style>
# <table id="T_80309">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80309_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >usageFullyQualifiedName</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80309_level0_row0" class="row_heading level0 row0" >org.apache.commons.cli.Options.addOption(org.apache.commons.cli.Option)</th>
#       <td id="T_80309_row0_col0" class="data row0 col0" >8944</td>
#     </tr>
#     <tr>
#       <th id="T_80309_level0_row1" class="row_heading level0 row1" >org.apache.commons.cli.Option</th>
#       <td id="T_80309_row1_col0" class="data row1 col0" >8486</td>
#     </tr>
#     <tr>
#       <th id="T_80309_level0_row2" class="row_heading level0 row2" >org.apache.commons.cli.Options</th>
#       <td id="T_80309_row2_col0" class="data row2 col0" >5812</td>
#     </tr>
#     <tr>
#       <th id="T_80309_level0_row3" class="row_heading level0 row3" >org.apache.commons.cli.Option.setRequired(boolean)</th>
#       <td id="T_80309_row3_col0" class="data row3 col0" >5182</td>
#     </tr>
#     <tr>
#       <th id="T_80309_level0_row4" class="row_heading level0 row4" >org.apache.commons.cli.CommandLine.getOptionValue(char)</th>
#       <td id="T_80309_row4_col0" class="data row4 col0" >5166</td>
#     </tr>
#     <tr>
#       <th id="T_80309_level0_row5" class="row_heading level0 row5" >org.apache.commons.cli.CommandLine.hasOption(java.lang.String)</th>
#       <td id="T_80309_row5_col0" class="data row5 col0" >4470</td>
#     </tr>
#     <tr>
#       <th id="T_80309_level0_row6" class="row_heading level0 row6" >org.apache.commons.cli.CommandLine.hasOption(char)</th>
#       <td id="T_80309_row6_col0" class="data row6 col0" >3960</td>
#     </tr>
#     <tr>
#       <th id="T_80309_level0_row7" class="row_heading level0 row7" >org.apache.commons.cli.CommandLine.getOptionValue(java.lang.String)</th>
#       <td id="T_80309_row7_col0" class="data row7 col0" >3690</td>
#     </tr>
#     <tr>
#       <th id="T_80309_level0_row8" class="row_heading level0 row8" >org.apache.commons.cli.Option(java.lang.String,java.lang.String,boolean,java.lang.String)</th>
#       <td id="T_80309_row8_col0" class="data row8 col0" >2972</td>
#     </tr>
#     <tr>
#       <th id="T_80309_level0_row9" class="row_heading level0 row9" >org.apache.commons.cli.CommandLine</th>
#       <td id="T_80309_row9_col0" class="data row9 col0" >2274</td>
#     </tr>
#     <tr>
#       <th id="T_80309_level0_row10" class="row_heading level0 row10" >org.apache.commons.cli.Options.addOption(java.lang.String,java.lang.String,boolean,java.lang.String)</th>
#       <td id="T_80309_row10_col0" class="data row10 col0" >2040</td>
#     </tr>
#     <tr>
#       <th id="T_80309_level0_row11" class="row_heading level0 row11" >org.apache.commons.cli.Option$Builder.build()</th>
#       <td id="T_80309_row11_col0" class="data row11 col0" >1552</td>
#     </tr>
#     <tr>
#       <th id="T_80309_level0_row12" class="row_heading level0 row12" >org.apache.commons.cli.PosixParser</th>
#       <td id="T_80309_row12_col0" class="data row12 col0" >1362</td>
#     </tr>
#     <tr>
#       <th id="T_80309_level0_row13" class="row_heading level0 row13" >org.apache.commons.cli.Option$Builder.desc(java.lang.String)</th>
#       <td id="T_80309_row13_col0" class="data row13 col0" >1360</td>
#     </tr>
#     <tr>
#       <th id="T_80309_level0_row14" class="row_heading level0 row14" >org.apache.commons.cli.HelpFormatter</th>
#       <td id="T_80309_row14_col0" class="data row14 col0" >1215</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Most popular API interactions

# %%
print("In all SUFs")
display(suf.groupby(["usageFullyQualifiedName","qualifiedUse"]).size().sort_values(ascending=False).to_frame().head(n=15).style.bar())
print("In clients")
display(suf_client.groupby(["usageFullyQualifiedName","qualifiedUse"]).size().sort_values(ascending=False).to_frame().head(n=15).style.bar())
print("In samples")
display(suf_sample.groupby(["usageFullyQualifiedName","qualifiedUse"]).size().sort_values(ascending=False).to_frame().head(n=15).style.bar())
print("In tests")
display(suf_test.groupby(["usageFullyQualifiedName","qualifiedUse"]).size().sort_values(ascending=False).to_frame().head(n=15).style.bar())
# Out:
# In all SUFs
# <style type="text/css">
# #T_c64ee_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_c64ee_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 89.3%, transparent 89.3%);
# }
# #T_c64ee_row2_col0, #T_c64ee_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 85.5%, transparent 85.5%);
# }
# #T_c64ee_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 62.2%, transparent 62.2%);
# }
# #T_c64ee_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 56.8%, transparent 56.8%);
# }
# #T_c64ee_row6_col0, #T_c64ee_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 49.5%, transparent 49.5%);
# }
# #T_c64ee_row8_col0, #T_c64ee_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 49.4%, transparent 49.4%);
# }
# #T_c64ee_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 43.4%, transparent 43.4%);
# }
# #T_c64ee_row11_col0, #T_c64ee_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 42.7%, transparent 42.7%);
# }
# #T_c64ee_row13_col0, #T_c64ee_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 37.8%, transparent 37.8%);
# }
# </style>
# <table id="T_c64ee">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c64ee_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >usageFullyQualifiedName</th>
#       <th class="index_name level1" >qualifiedUse</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c64ee_level0_row0" class="row_heading level0 row0" >org.apache.commons.cli.Option</th>
#       <th id="T_c64ee_level1_row0" class="row_heading level1 row0" >SYMBOL_KIND_TYPE > SYMBOL_USE_TYPE_REFERENCE</th>
#       <td id="T_c64ee_row0_col0" class="data row0 col0" >5232</td>
#     </tr>
#     <tr>
#       <th id="T_c64ee_level0_row1" class="row_heading level0 row1" >org.apache.commons.cli.Options</th>
#       <th id="T_c64ee_level1_row1" class="row_heading level1 row1" >SYMBOL_KIND_TYPE > SYMBOL_USE_TYPE_REFERENCE</th>
#       <td id="T_c64ee_row1_col0" class="data row1 col0" >4671</td>
#     </tr>
#     <tr>
#       <th id="T_c64ee_level0_row2" class="row_heading level0 row2" rowspan="2">org.apache.commons.cli.Options.addOption(org.apache.commons.cli.Option)</th>
#       <th id="T_c64ee_level1_row2" class="row_heading level1 row2" >SYMBOL_KIND_METHOD > SYMBOL_USE_INVOCATION</th>
#       <td id="T_c64ee_row2_col0" class="data row2 col0" >4472</td>
#     </tr>
#     <tr>
#       <th id="T_c64ee_level1_row3" class="row_heading level1 row3" >SYMBOL_KIND_METHOD > SYMBOL_USE_VIRTUAL_INVOCATION</th>
#       <td id="T_c64ee_row3_col0" class="data row3 col0" >4472</td>
#     </tr>
#     <tr>
#       <th id="T_c64ee_level0_row4" class="row_heading level0 row4" >org.apache.commons.cli.Option</th>
#       <th id="T_c64ee_level1_row4" class="row_heading level1 row4" >SYMBOL_KIND_CLASS > SYMBOL_USE_INSTANTIATION</th>
#       <td id="T_c64ee_row4_col0" class="data row4 col0" >3252</td>
#     </tr>
#     <tr>
#       <th id="T_c64ee_level0_row5" class="row_heading level0 row5" >org.apache.commons.cli.Option(java.lang.String,java.lang.String,boolean,java.lang.String)</th>
#       <th id="T_c64ee_level1_row5" class="row_heading level1 row5" >SYMBOL_KIND_CONSTRUCTOR > SYMBOL_USE_INVOCATION</th>
#       <td id="T_c64ee_row5_col0" class="data row5 col0" >2972</td>
#     </tr>
#     <tr>
#       <th id="T_c64ee_level0_row6" class="row_heading level0 row6" rowspan="2">org.apache.commons.cli.Option.setRequired(boolean)</th>
#       <th id="T_c64ee_level1_row6" class="row_heading level1 row6" >SYMBOL_KIND_METHOD > SYMBOL_USE_VIRTUAL_INVOCATION</th>
#       <td id="T_c64ee_row6_col0" class="data row6 col0" >2591</td>
#     </tr>
#     <tr>
#       <th id="T_c64ee_level1_row7" class="row_heading level1 row7" >SYMBOL_KIND_METHOD > SYMBOL_USE_INVOCATION</th>
#       <td id="T_c64ee_row7_col0" class="data row7 col0" >2591</td>
#     </tr>
#     <tr>
#       <th id="T_c64ee_level0_row8" class="row_heading level0 row8" rowspan="2">org.apache.commons.cli.CommandLine.getOptionValue(char)</th>
#       <th id="T_c64ee_level1_row8" class="row_heading level1 row8" >SYMBOL_KIND_METHOD > SYMBOL_USE_VIRTUAL_INVOCATION</th>
#       <td id="T_c64ee_row8_col0" class="data row8 col0" >2583</td>
#     </tr>
#     <tr>
#       <th id="T_c64ee_level1_row9" class="row_heading level1 row9" >SYMBOL_KIND_METHOD > SYMBOL_USE_INVOCATION</th>
#       <td id="T_c64ee_row9_col0" class="data row9 col0" >2583</td>
#     </tr>
#     <tr>
#       <th id="T_c64ee_level0_row10" class="row_heading level0 row10" >org.apache.commons.cli.CommandLine</th>
#       <th id="T_c64ee_level1_row10" class="row_heading level1 row10" >SYMBOL_KIND_TYPE > SYMBOL_USE_TYPE_REFERENCE</th>
#       <td id="T_c64ee_row10_col0" class="data row10 col0" >2273</td>
#     </tr>
#     <tr>
#       <th id="T_c64ee_level0_row11" class="row_heading level0 row11" rowspan="2">org.apache.commons.cli.CommandLine.hasOption(java.lang.String)</th>
#       <th id="T_c64ee_level1_row11" class="row_heading level1 row11" >SYMBOL_KIND_METHOD > SYMBOL_USE_VIRTUAL_INVOCATION</th>
#       <td id="T_c64ee_row11_col0" class="data row11 col0" >2235</td>
#     </tr>
#     <tr>
#       <th id="T_c64ee_level1_row12" class="row_heading level1 row12" >SYMBOL_KIND_METHOD > SYMBOL_USE_INVOCATION</th>
#       <td id="T_c64ee_row12_col0" class="data row12 col0" >2235</td>
#     </tr>
#     <tr>
#       <th id="T_c64ee_level0_row13" class="row_heading level0 row13" rowspan="2">org.apache.commons.cli.CommandLine.hasOption(char)</th>
#       <th id="T_c64ee_level1_row13" class="row_heading level1 row13" >SYMBOL_KIND_METHOD > SYMBOL_USE_VIRTUAL_INVOCATION</th>
#       <td id="T_c64ee_row13_col0" class="data row13 col0" >1980</td>
#     </tr>
#     <tr>
#       <th id="T_c64ee_level1_row14" class="row_heading level1 row14" >SYMBOL_KIND_METHOD > SYMBOL_USE_INVOCATION</th>
#       <td id="T_c64ee_row14_col0" class="data row14 col0" >1980</td>
#     </tr>
#   </tbody>
# </table>
# In clients
# <style type="text/css">
# #T_4a2b9_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_4a2b9_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 87.5%, transparent 87.5%);
# }
# #T_4a2b9_row2_col0, #T_4a2b9_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 84.7%, transparent 84.7%);
# }
# #T_4a2b9_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 62.8%, transparent 62.8%);
# }
# #T_4a2b9_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 57.9%, transparent 57.9%);
# }
# #T_4a2b9_row6_col0, #T_4a2b9_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 51.2%, transparent 51.2%);
# }
# #T_4a2b9_row8_col0, #T_4a2b9_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 50.9%, transparent 50.9%);
# }
# #T_4a2b9_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 42.4%, transparent 42.4%);
# }
# #T_4a2b9_row11_col0, #T_4a2b9_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 40.9%, transparent 40.9%);
# }
# #T_4a2b9_row13_col0, #T_4a2b9_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 38.9%, transparent 38.9%);
# }
# </style>
# <table id="T_4a2b9">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a2b9_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >usageFullyQualifiedName</th>
#       <th class="index_name level1" >qualifiedUse</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a2b9_level0_row0" class="row_heading level0 row0" >org.apache.commons.cli.Option</th>
#       <th id="T_4a2b9_level1_row0" class="row_heading level1 row0" >SYMBOL_KIND_TYPE > SYMBOL_USE_TYPE_REFERENCE</th>
#       <td id="T_4a2b9_row0_col0" class="data row0 col0" >5053</td>
#     </tr>
#     <tr>
#       <th id="T_4a2b9_level0_row1" class="row_heading level0 row1" >org.apache.commons.cli.Options</th>
#       <th id="T_4a2b9_level1_row1" class="row_heading level1 row1" >SYMBOL_KIND_TYPE > SYMBOL_USE_TYPE_REFERENCE</th>
#       <td id="T_4a2b9_row1_col0" class="data row1 col0" >4423</td>
#     </tr>
#     <tr>
#       <th id="T_4a2b9_level0_row2" class="row_heading level0 row2" rowspan="2">org.apache.commons.cli.Options.addOption(org.apache.commons.cli.Option)</th>
#       <th id="T_4a2b9_level1_row2" class="row_heading level1 row2" >SYMBOL_KIND_METHOD > SYMBOL_USE_VIRTUAL_INVOCATION</th>
#       <td id="T_4a2b9_row2_col0" class="data row2 col0" >4280</td>
#     </tr>
#     <tr>
#       <th id="T_4a2b9_level1_row3" class="row_heading level1 row3" >SYMBOL_KIND_METHOD > SYMBOL_USE_INVOCATION</th>
#       <td id="T_4a2b9_row3_col0" class="data row3 col0" >4280</td>
#     </tr>
#     <tr>
#       <th id="T_4a2b9_level0_row4" class="row_heading level0 row4" >org.apache.commons.cli.Option</th>
#       <th id="T_4a2b9_level1_row4" class="row_heading level1 row4" >SYMBOL_KIND_CLASS > SYMBOL_USE_INSTANTIATION</th>
#       <td id="T_4a2b9_row4_col0" class="data row4 col0" >3173</td>
#     </tr>
#     <tr>
#       <th id="T_4a2b9_level0_row5" class="row_heading level0 row5" >org.apache.commons.cli.Option(java.lang.String,java.lang.String,boolean,java.lang.String)</th>
#       <th id="T_4a2b9_level1_row5" class="row_heading level1 row5" >SYMBOL_KIND_CONSTRUCTOR > SYMBOL_USE_INVOCATION</th>
#       <td id="T_4a2b9_row5_col0" class="data row5 col0" >2924</td>
#     </tr>
#     <tr>
#       <th id="T_4a2b9_level0_row6" class="row_heading level0 row6" rowspan="2">org.apache.commons.cli.Option.setRequired(boolean)</th>
#       <th id="T_4a2b9_level1_row6" class="row_heading level1 row6" >SYMBOL_KIND_METHOD > SYMBOL_USE_VIRTUAL_INVOCATION</th>
#       <td id="T_4a2b9_row6_col0" class="data row6 col0" >2589</td>
#     </tr>
#     <tr>
#       <th id="T_4a2b9_level1_row7" class="row_heading level1 row7" >SYMBOL_KIND_METHOD > SYMBOL_USE_INVOCATION</th>
#       <td id="T_4a2b9_row7_col0" class="data row7 col0" >2589</td>
#     </tr>
#     <tr>
#       <th id="T_4a2b9_level0_row8" class="row_heading level0 row8" rowspan="2">org.apache.commons.cli.CommandLine.getOptionValue(char)</th>
#       <th id="T_4a2b9_level1_row8" class="row_heading level1 row8" >SYMBOL_KIND_METHOD > SYMBOL_USE_VIRTUAL_INVOCATION</th>
#       <td id="T_4a2b9_row8_col0" class="data row8 col0" >2573</td>
#     </tr>
#     <tr>
#       <th id="T_4a2b9_level1_row9" class="row_heading level1 row9" >SYMBOL_KIND_METHOD > SYMBOL_USE_INVOCATION</th>
#       <td id="T_4a2b9_row9_col0" class="data row9 col0" >2573</td>
#     </tr>
#     <tr>
#       <th id="T_4a2b9_level0_row10" class="row_heading level0 row10" >org.apache.commons.cli.CommandLine</th>
#       <th id="T_4a2b9_level1_row10" class="row_heading level1 row10" >SYMBOL_KIND_TYPE > SYMBOL_USE_TYPE_REFERENCE</th>
#       <td id="T_4a2b9_row10_col0" class="data row10 col0" >2141</td>
#     </tr>
#     <tr>
#       <th id="T_4a2b9_level0_row11" class="row_heading level0 row11" rowspan="2">org.apache.commons.cli.CommandLine.hasOption(java.lang.String)</th>
#       <th id="T_4a2b9_level1_row11" class="row_heading level1 row11" >SYMBOL_KIND_METHOD > SYMBOL_USE_VIRTUAL_INVOCATION</th>
#       <td id="T_4a2b9_row11_col0" class="data row11 col0" >2069</td>
#     </tr>
#     <tr>
#       <th id="T_4a2b9_level1_row12" class="row_heading level1 row12" >SYMBOL_KIND_METHOD > SYMBOL_USE_INVOCATION</th>
#       <td id="T_4a2b9_row12_col0" class="data row12 col0" >2069</td>
#     </tr>
#     <tr>
#       <th id="T_4a2b9_level0_row13" class="row_heading level0 row13" rowspan="2">org.apache.commons.cli.CommandLine.hasOption(char)</th>
#       <th id="T_4a2b9_level1_row13" class="row_heading level1 row13" >SYMBOL_KIND_METHOD > SYMBOL_USE_VIRTUAL_INVOCATION</th>
#       <td id="T_4a2b9_row13_col0" class="data row13 col0" >1968</td>
#     </tr>
#     <tr>
#       <th id="T_4a2b9_level1_row14" class="row_heading level1 row14" >SYMBOL_KIND_METHOD > SYMBOL_USE_INVOCATION</th>
#       <td id="T_4a2b9_row14_col0" class="data row14 col0" >1968</td>
#     </tr>
#   </tbody>
# </table>
# In samples
# <style type="text/css">
# #T_8be4f_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_8be4f_row1_col0, #T_8be4f_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 64.7%, transparent 64.7%);
# }
# #T_8be4f_row3_col0, #T_8be4f_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 58.8%, transparent 58.8%);
# }
# #T_8be4f_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 41.2%, transparent 41.2%);
# }
# #T_8be4f_row6_col0, #T_8be4f_row7_col0, #T_8be4f_row8_col0, #T_8be4f_row9_col0, #T_8be4f_row10_col0, #T_8be4f_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 23.5%, transparent 23.5%);
# }
# #T_8be4f_row12_col0, #T_8be4f_row13_col0, #T_8be4f_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 17.6%, transparent 17.6%);
# }
# </style>
# <table id="T_8be4f">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8be4f_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >usageFullyQualifiedName</th>
#       <th class="index_name level1" >qualifiedUse</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8be4f_level0_row0" class="row_heading level0 row0" >org.apache.commons.cli.Option</th>
#       <th id="T_8be4f_level1_row0" class="row_heading level1 row0" >SYMBOL_KIND_TYPE > SYMBOL_USE_TYPE_REFERENCE</th>
#       <td id="T_8be4f_row0_col0" class="data row0 col0" >17</td>
#     </tr>
#     <tr>
#       <th id="T_8be4f_level0_row1" class="row_heading level0 row1" rowspan="2">org.apache.commons.cli.Options.addOption(org.apache.commons.cli.Option)</th>
#       <th id="T_8be4f_level1_row1" class="row_heading level1 row1" >SYMBOL_KIND_METHOD > SYMBOL_USE_VIRTUAL_INVOCATION</th>
#       <td id="T_8be4f_row1_col0" class="data row1 col0" >11</td>
#     </tr>
#     <tr>
#       <th id="T_8be4f_level1_row2" class="row_heading level1 row2" >SYMBOL_KIND_METHOD > SYMBOL_USE_INVOCATION</th>
#       <td id="T_8be4f_row2_col0" class="data row2 col0" >11</td>
#     </tr>
#     <tr>
#       <th id="T_8be4f_level0_row3" class="row_heading level0 row3" >org.apache.commons.cli.Option</th>
#       <th id="T_8be4f_level1_row3" class="row_heading level1 row3" >SYMBOL_KIND_CLASS > SYMBOL_USE_INSTANTIATION</th>
#       <td id="T_8be4f_row3_col0" class="data row3 col0" >10</td>
#     </tr>
#     <tr>
#       <th id="T_8be4f_level0_row4" class="row_heading level0 row4" >org.apache.commons.cli.Options</th>
#       <th id="T_8be4f_level1_row4" class="row_heading level1 row4" >SYMBOL_KIND_TYPE > SYMBOL_USE_TYPE_REFERENCE</th>
#       <td id="T_8be4f_row4_col0" class="data row4 col0" >10</td>
#     </tr>
#     <tr>
#       <th id="T_8be4f_level0_row5" class="row_heading level0 row5" >org.apache.commons.cli.Option(java.lang.String,java.lang.String)</th>
#       <th id="T_8be4f_level1_row5" class="row_heading level1 row5" >SYMBOL_KIND_CONSTRUCTOR > SYMBOL_USE_INVOCATION</th>
#       <td id="T_8be4f_row5_col0" class="data row5 col0" >7</td>
#     </tr>
#     <tr>
#       <th id="T_8be4f_level0_row6" class="row_heading level0 row6" rowspan="2">org.apache.commons.cli.Options.addOption(java.lang.String,java.lang.String,boolean,java.lang.String)</th>
#       <th id="T_8be4f_level1_row6" class="row_heading level1 row6" >SYMBOL_KIND_METHOD > SYMBOL_USE_VIRTUAL_INVOCATION</th>
#       <td id="T_8be4f_row6_col0" class="data row6 col0" >4</td>
#     </tr>
#     <tr>
#       <th id="T_8be4f_level1_row7" class="row_heading level1 row7" >SYMBOL_KIND_METHOD > SYMBOL_USE_INVOCATION</th>
#       <td id="T_8be4f_row7_col0" class="data row7 col0" >4</td>
#     </tr>
#     <tr>
#       <th id="T_8be4f_level0_row8" class="row_heading level0 row8" rowspan="2">org.apache.commons.cli.Options.addOption(java.lang.String,boolean,java.lang.String)</th>
#       <th id="T_8be4f_level1_row8" class="row_heading level1 row8" >SYMBOL_KIND_METHOD > SYMBOL_USE_VIRTUAL_INVOCATION</th>
#       <td id="T_8be4f_row8_col0" class="data row8 col0" >4</td>
#     </tr>
#     <tr>
#       <th id="T_8be4f_level1_row9" class="row_heading level1 row9" >SYMBOL_KIND_METHOD > SYMBOL_USE_INVOCATION</th>
#       <td id="T_8be4f_row9_col0" class="data row9 col0" >4</td>
#     </tr>
#     <tr>
#       <th id="T_8be4f_level0_row10" class="row_heading level0 row10" >org.apache.commons.cli.Options()</th>
#       <th id="T_8be4f_level1_row10" class="row_heading level1 row10" >SYMBOL_KIND_CONSTRUCTOR > SYMBOL_USE_INVOCATION</th>
#       <td id="T_8be4f_row10_col0" class="data row10 col0" >4</td>
#     </tr>
#     <tr>
#       <th id="T_8be4f_level0_row11" class="row_heading level0 row11" >org.apache.commons.cli.Options</th>
#       <th id="T_8be4f_level1_row11" class="row_heading level1 row11" >SYMBOL_KIND_CLASS > SYMBOL_USE_INSTANTIATION</th>
#       <td id="T_8be4f_row11_col0" class="data row11 col0" >4</td>
#     </tr>
#     <tr>
#       <th id="T_8be4f_level0_row12" class="row_heading level0 row12" >org.apache.commons.cli.CommandLine</th>
#       <th id="T_8be4f_level1_row12" class="row_heading level1 row12" >SYMBOL_KIND_TYPE > SYMBOL_USE_TYPE_REFERENCE</th>
#       <td id="T_8be4f_row12_col0" class="data row12 col0" >3</td>
#     </tr>
#     <tr>
#       <th id="T_8be4f_level0_row13" class="row_heading level0 row13" >org.apache.commons.cli.Option(java.lang.String,java.lang.String,boolean,java.lang.String)</th>
#       <th id="T_8be4f_level1_row13" class="row_heading level1 row13" >SYMBOL_KIND_CONSTRUCTOR > SYMBOL_USE_INVOCATION</th>
#       <td id="T_8be4f_row13_col0" class="data row13 col0" >3</td>
#     </tr>
#     <tr>
#       <th id="T_8be4f_level0_row14" class="row_heading level0 row14" >org.apache.commons.cli.CommandLine.getOptionValue(java.lang.String)</th>
#       <th id="T_8be4f_level1_row14" class="row_heading level1 row14" >SYMBOL_KIND_METHOD > SYMBOL_USE_INVOCATION</th>
#       <td id="T_8be4f_row14_col0" class="data row14 col0" >3</td>
#     </tr>
#   </tbody>
# </table>
# In tests
# <style type="text/css">
# #T_358d5_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_358d5_row1_col0, #T_358d5_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 76.1%, transparent 76.1%);
# }
# #T_358d5_row3_col0, #T_358d5_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 68.5%, transparent 68.5%);
# }
# #T_358d5_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 68.1%, transparent 68.1%);
# }
# #T_358d5_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 58.8%, transparent 58.8%);
# }
# #T_358d5_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 54.2%, transparent 54.2%);
# }
# #T_358d5_row8_col0, #T_358d5_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 48.3%, transparent 48.3%);
# }
# #T_358d5_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 33.6%, transparent 33.6%);
# }
# #T_358d5_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 30.7%, transparent 30.7%);
# }
# #T_358d5_row12_col0, #T_358d5_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 30.3%, transparent 30.3%);
# }
# #T_358d5_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 29.0%, transparent 29.0%);
# }
# </style>
# <table id="T_358d5">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_358d5_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >usageFullyQualifiedName</th>
#       <th class="index_name level1" >qualifiedUse</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_358d5_level0_row0" class="row_heading level0 row0" >org.apache.commons.cli.Options</th>
#       <th id="T_358d5_level1_row0" class="row_heading level1 row0" >SYMBOL_KIND_TYPE > SYMBOL_USE_TYPE_REFERENCE</th>
#       <td id="T_358d5_row0_col0" class="data row0 col0" >238</td>
#     </tr>
#     <tr>
#       <th id="T_358d5_level0_row1" class="row_heading level0 row1" rowspan="2">org.apache.commons.cli.Options.addOption(org.apache.commons.cli.Option)</th>
#       <th id="T_358d5_level1_row1" class="row_heading level1 row1" >SYMBOL_KIND_METHOD > SYMBOL_USE_INVOCATION</th>
#       <td id="T_358d5_row1_col0" class="data row1 col0" >181</td>
#     </tr>
#     <tr>
#       <th id="T_358d5_level1_row2" class="row_heading level1 row2" >SYMBOL_KIND_METHOD > SYMBOL_USE_VIRTUAL_INVOCATION</th>
#       <td id="T_358d5_row2_col0" class="data row2 col0" >181</td>
#     </tr>
#     <tr>
#       <th id="T_358d5_level0_row3" class="row_heading level0 row3" rowspan="2">org.apache.commons.cli.CommandLine.hasOption(java.lang.String)</th>
#       <th id="T_358d5_level1_row3" class="row_heading level1 row3" >SYMBOL_KIND_METHOD > SYMBOL_USE_VIRTUAL_INVOCATION</th>
#       <td id="T_358d5_row3_col0" class="data row3 col0" >163</td>
#     </tr>
#     <tr>
#       <th id="T_358d5_level1_row4" class="row_heading level1 row4" >SYMBOL_KIND_METHOD > SYMBOL_USE_INVOCATION</th>
#       <td id="T_358d5_row4_col0" class="data row4 col0" >163</td>
#     </tr>
#     <tr>
#       <th id="T_358d5_level0_row5" class="row_heading level0 row5" >org.apache.commons.cli.Option</th>
#       <th id="T_358d5_level1_row5" class="row_heading level1 row5" >SYMBOL_KIND_TYPE > SYMBOL_USE_TYPE_REFERENCE</th>
#       <td id="T_358d5_row5_col0" class="data row5 col0" >162</td>
#     </tr>
#     <tr>
#       <th id="T_358d5_level0_row6" class="row_heading level0 row6" >org.apache.commons.cli.CommandLineParser.parse(org.apache.commons.cli.Options,java.lang.String[])</th>
#       <th id="T_358d5_level1_row6" class="row_heading level1 row6" >SYMBOL_KIND_METHOD > SYMBOL_USE_VIRTUAL_INVOCATION</th>
#       <td id="T_358d5_row6_col0" class="data row6 col0" >140</td>
#     </tr>
#     <tr>
#       <th id="T_358d5_level0_row7" class="row_heading level0 row7" >org.apache.commons.cli.CommandLine</th>
#       <th id="T_358d5_level1_row7" class="row_heading level1 row7" >SYMBOL_KIND_TYPE > SYMBOL_USE_TYPE_REFERENCE</th>
#       <td id="T_358d5_row7_col0" class="data row7 col0" >129</td>
#     </tr>
#     <tr>
#       <th id="T_358d5_level0_row8" class="row_heading level0 row8" >org.apache.commons.cli.Options</th>
#       <th id="T_358d5_level1_row8" class="row_heading level1 row8" >SYMBOL_KIND_CLASS > SYMBOL_USE_INSTANTIATION</th>
#       <td id="T_358d5_row8_col0" class="data row8 col0" >115</td>
#     </tr>
#     <tr>
#       <th id="T_358d5_level0_row9" class="row_heading level0 row9" >org.apache.commons.cli.Options()</th>
#       <th id="T_358d5_level1_row9" class="row_heading level1 row9" >SYMBOL_KIND_CONSTRUCTOR > SYMBOL_USE_INVOCATION</th>
#       <td id="T_358d5_row9_col0" class="data row9 col0" >115</td>
#     </tr>
#     <tr>
#       <th id="T_358d5_level0_row10" class="row_heading level0 row10" >org.apache.commons.cli.OptionBuilder.create(char)</th>
#       <th id="T_358d5_level1_row10" class="row_heading level1 row10" >SYMBOL_KIND_METHOD > SYMBOL_USE_STATIC_INVOCATION</th>
#       <td id="T_358d5_row10_col0" class="data row10 col0" >80</td>
#     </tr>
#     <tr>
#       <th id="T_358d5_level0_row11" class="row_heading level0 row11" >org.apache.commons.cli.OptionBuilder.withLongOpt(java.lang.String)</th>
#       <th id="T_358d5_level1_row11" class="row_heading level1 row11" >SYMBOL_KIND_METHOD > SYMBOL_USE_STATIC_INVOCATION</th>
#       <td id="T_358d5_row11_col0" class="data row11 col0" >73</td>
#     </tr>
#     <tr>
#       <th id="T_358d5_level0_row12" class="row_heading level0 row12" rowspan="2">org.apache.commons.cli.CommandLine.getOptionValue(java.lang.String)</th>
#       <th id="T_358d5_level1_row12" class="row_heading level1 row12" >SYMBOL_KIND_METHOD > SYMBOL_USE_INVOCATION</th>
#       <td id="T_358d5_row12_col0" class="data row12 col0" >72</td>
#     </tr>
#     <tr>
#       <th id="T_358d5_level1_row13" class="row_heading level1 row13" >SYMBOL_KIND_METHOD > SYMBOL_USE_VIRTUAL_INVOCATION</th>
#       <td id="T_358d5_row13_col0" class="data row13 col0" >72</td>
#     </tr>
#     <tr>
#       <th id="T_358d5_level0_row14" class="row_heading level0 row14" >org.apache.commons.cli.Options.addOption(java.lang.String,java.lang.String,boolean,java.lang.String)</th>
#       <th id="T_358d5_level1_row14" class="row_heading level1 row14" >SYMBOL_KIND_METHOD > SYMBOL_USE_INVOCATION</th>
#       <td id="T_358d5_row14_col0" class="data row14 col0" >69</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Least popular API symbols in all SUFs
#
#   - Notice how some clients are invoking `*.internal.*` stuff!

# %%
suf.groupby(["usageFullyQualifiedName"]).size().sort_values(ascending=True).to_frame().head(n=15).style.bar()
# Out:
# <style type="text/css">
# #T_fac7b_row0_col0, #T_fac7b_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_fac7b_row2_col0, #T_fac7b_row3_col0, #T_fac7b_row4_col0, #T_fac7b_row5_col0, #T_fac7b_row6_col0, #T_fac7b_row7_col0, #T_fac7b_row8_col0, #T_fac7b_row9_col0, #T_fac7b_row10_col0, #T_fac7b_row11_col0, #T_fac7b_row12_col0, #T_fac7b_row13_col0, #T_fac7b_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_fac7b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fac7b_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >usageFullyQualifiedName</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fac7b_level0_row0" class="row_heading level0 row0" >org.apache.commons.cli.OptionBuilder</th>
#       <td id="T_fac7b_row0_col0" class="data row0 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_fac7b_level0_row1" class="row_heading level0 row1" >org.apache.commons.cli.CommandLine()</th>
#       <td id="T_fac7b_row1_col0" class="data row1 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_fac7b_level0_row2" class="row_heading level0 row2" >org.apache.commons.cli.AlreadySelectedException</th>
#       <td id="T_fac7b_row2_col0" class="data row2 col0" >2</td>
#     </tr>
#     <tr>
#       <th id="T_fac7b_level0_row3" class="row_heading level0 row3" >org.apache.commons.cli.Option.setDescription(java.lang.String)</th>
#       <td id="T_fac7b_row3_col0" class="data row3 col0" >2</td>
#     </tr>
#     <tr>
#       <th id="T_fac7b_level0_row4" class="row_heading level0 row4" >org.apache.commons.cli.DefaultParser$Builder.setAllowPartialMatching(boolean)</th>
#       <td id="T_fac7b_row4_col0" class="data row4 col0" >2</td>
#     </tr>
#     <tr>
#       <th id="T_fac7b_level0_row5" class="row_heading level0 row5" >org.apache.commons.cli.Option.hasOptionalArg()</th>
#       <td id="T_fac7b_row5_col0" class="data row5 col0" >2</td>
#     </tr>
#     <tr>
#       <th id="T_fac7b_level0_row6" class="row_heading level0 row6" >org.apache.commons.cli.UnrecognizedOptionException(java.lang.String)</th>
#       <td id="T_fac7b_row6_col0" class="data row6 col0" >2</td>
#     </tr>
#     <tr>
#       <th id="T_fac7b_level0_row7" class="row_heading level0 row7" >org.apache.commons.cli.DefaultParser.parse(org.apache.commons.cli.Options,java.lang.String[],java.util.Properties)</th>
#       <td id="T_fac7b_row7_col0" class="data row7 col0" >2</td>
#     </tr>
#     <tr>
#       <th id="T_fac7b_level0_row8" class="row_heading level0 row8" >org.apache.commons.cli.Option.getValues()</th>
#       <td id="T_fac7b_row8_col0" class="data row8 col0" >2</td>
#     </tr>
#     <tr>
#       <th id="T_fac7b_level0_row9" class="row_heading level0 row9" >org.apache.commons.cli.HelpFormatter.getArgName()</th>
#       <td id="T_fac7b_row9_col0" class="data row9 col0" >2</td>
#     </tr>
#     <tr>
#       <th id="T_fac7b_level0_row10" class="row_heading level0 row10" >org.apache.commons.cli.HelpFormatter.getLongOptPrefix()</th>
#       <td id="T_fac7b_row10_col0" class="data row10 col0" >2</td>
#     </tr>
#     <tr>
#       <th id="T_fac7b_level0_row11" class="row_heading level0 row11" >org.apache.commons.cli.HelpFormatter.getNewLine()</th>
#       <td id="T_fac7b_row11_col0" class="data row11 col0" >2</td>
#     </tr>
#     <tr>
#       <th id="T_fac7b_level0_row12" class="row_heading level0 row12" >org.apache.commons.cli.HelpFormatter.getOptPrefix()</th>
#       <td id="T_fac7b_row12_col0" class="data row12 col0" >2</td>
#     </tr>
#     <tr>
#       <th id="T_fac7b_level0_row13" class="row_heading level0 row13" >org.apache.commons.cli.HelpFormatter.getOptionComparator()</th>
#       <td id="T_fac7b_row13_col0" class="data row13 col0" >2</td>
#     </tr>
#     <tr>
#       <th id="T_fac7b_level0_row14" class="row_heading level0 row14" >org.apache.commons.cli.HelpFormatter.getSyntaxPrefix()</th>
#       <td id="T_fac7b_row14_col0" class="data row14 col0" >2</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Least popular API interactions in all SUFs

# %%
suf.groupby(["usageFullyQualifiedName","qualifiedUse"]).size().sort_values(ascending=True).to_frame().head(n=15).style.bar()
# Out:
# <style type="text/css">
# #T_fc787_row0_col0, #T_fc787_row1_col0, #T_fc787_row2_col0, #T_fc787_row3_col0, #T_fc787_row4_col0, #T_fc787_row5_col0, #T_fc787_row6_col0, #T_fc787_row7_col0, #T_fc787_row8_col0, #T_fc787_row9_col0, #T_fc787_row10_col0, #T_fc787_row11_col0, #T_fc787_row12_col0, #T_fc787_row13_col0, #T_fc787_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_fc787">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc787_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >usageFullyQualifiedName</th>
#       <th class="index_name level1" >qualifiedUse</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc787_level0_row0" class="row_heading level0 row0" >org.apache.commons.cli.GnuParser</th>
#       <th id="T_fc787_level1_row0" class="row_heading level1 row0" >SYMBOL_KIND_CLASS > SYMBOL_USE_INHERITANCE</th>
#       <td id="T_fc787_row0_col0" class="data row0 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_fc787_level0_row1" class="row_heading level0 row1" >org.apache.commons.cli.HelpFormatter.getOptPrefix()</th>
#       <th id="T_fc787_level1_row1" class="row_heading level1 row1" >SYMBOL_KIND_METHOD > SYMBOL_USE_INVOCATION</th>
#       <td id="T_fc787_row1_col0" class="data row1 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_fc787_level0_row2" class="row_heading level0 row2" >org.apache.commons.cli.Option.setDescription(java.lang.String)</th>
#       <th id="T_fc787_level1_row2" class="row_heading level1 row2" >SYMBOL_KIND_METHOD > SYMBOL_USE_VIRTUAL_INVOCATION</th>
#       <td id="T_fc787_row2_col0" class="data row2 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_fc787_level0_row3" class="row_heading level0 row3" >org.apache.commons.cli.HelpFormatter.getNewLine()</th>
#       <th id="T_fc787_level1_row3" class="row_heading level1 row3" >SYMBOL_KIND_METHOD > SYMBOL_USE_INVOCATION</th>
#       <td id="T_fc787_row3_col0" class="data row3 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_fc787_level0_row4" class="row_heading level0 row4" rowspan="2">org.apache.commons.cli.Parser.getOptions()</th>
#       <th id="T_fc787_level1_row4" class="row_heading level1 row4" >SYMBOL_KIND_METHOD > SYMBOL_USE_VIRTUAL_INVOCATION</th>
#       <td id="T_fc787_row4_col0" class="data row4 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_fc787_level1_row5" class="row_heading level1 row5" >SYMBOL_KIND_METHOD > SYMBOL_USE_INVOCATION</th>
#       <td id="T_fc787_row5_col0" class="data row5 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_fc787_level0_row6" class="row_heading level0 row6" rowspan="2">org.apache.commons.cli.HelpFormatter.getLongOptPrefix()</th>
#       <th id="T_fc787_level1_row6" class="row_heading level1 row6" >SYMBOL_KIND_METHOD > SYMBOL_USE_VIRTUAL_INVOCATION</th>
#       <td id="T_fc787_row6_col0" class="data row6 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_fc787_level1_row7" class="row_heading level1 row7" >SYMBOL_KIND_METHOD > SYMBOL_USE_INVOCATION</th>
#       <td id="T_fc787_row7_col0" class="data row7 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_fc787_level0_row8" class="row_heading level0 row8" rowspan="2">org.apache.commons.cli.HelpFormatter.getArgName()</th>
#       <th id="T_fc787_level1_row8" class="row_heading level1 row8" >SYMBOL_KIND_METHOD > SYMBOL_USE_VIRTUAL_INVOCATION</th>
#       <td id="T_fc787_row8_col0" class="data row8 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_fc787_level1_row9" class="row_heading level1 row9" >SYMBOL_KIND_METHOD > SYMBOL_USE_INVOCATION</th>
#       <td id="T_fc787_row9_col0" class="data row9 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_fc787_level0_row10" class="row_heading level0 row10" >org.apache.commons.cli.Option.getValues()</th>
#       <th id="T_fc787_level1_row10" class="row_heading level1 row10" >SYMBOL_KIND_METHOD > SYMBOL_USE_VIRTUAL_INVOCATION</th>
#       <td id="T_fc787_row10_col0" class="data row10 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_fc787_level0_row11" class="row_heading level0 row11" >org.apache.commons.cli.HelpFormatter.getOptPrefix()</th>
#       <th id="T_fc787_level1_row11" class="row_heading level1 row11" >SYMBOL_KIND_METHOD > SYMBOL_USE_VIRTUAL_INVOCATION</th>
#       <td id="T_fc787_row11_col0" class="data row11 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_fc787_level0_row12" class="row_heading level0 row12" >org.apache.commons.cli.DefaultParser.parse(org.apache.commons.cli.Options,java.lang.String[],java.util.Properties)</th>
#       <th id="T_fc787_level1_row12" class="row_heading level1 row12" >SYMBOL_KIND_METHOD > SYMBOL_USE_VIRTUAL_INVOCATION</th>
#       <td id="T_fc787_row12_col0" class="data row12 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_fc787_level0_row13" class="row_heading level0 row13" >org.apache.commons.cli.OptionGroup.isRequired()</th>
#       <th id="T_fc787_level1_row13" class="row_heading level1 row13" >SYMBOL_KIND_METHOD > SYMBOL_USE_INVOCATION</th>
#       <td id="T_fc787_row13_col0" class="data row13 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_fc787_level0_row14" class="row_heading level0 row14" >org.apache.commons.cli.CommandLine.getOptionValue(org.apache.commons.cli.Option,java.lang.String)</th>
#       <th id="T_fc787_level1_row14" class="row_heading level1 row14" >SYMBOL_KIND_METHOD > SYMBOL_USE_INVOCATION</th>
#       <td id="T_fc787_row14_col0" class="data row14 col0" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Most popular interaction kinds in SUFs

# %%
print("In all SUFs")
display(suf["qualifiedUse"].value_counts().to_frame().style.bar())
print("In clients")
display(suf_client["qualifiedUse"].value_counts().to_frame().style.bar())
print("In samples")
display(suf_sample["qualifiedUse"].value_counts().to_frame().style.bar())
print("In tests")
display(suf_test["qualifiedUse"].value_counts().to_frame().style.bar())
# Out:
# In all SUFs
# <style type="text/css">
# #T_4a15f_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_4a15f_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 97.1%, transparent 97.1%);
# }
# #T_4a15f_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 64.7%, transparent 64.7%);
# }
# #T_4a15f_row3_col0, #T_4a15f_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 25.2%, transparent 25.2%);
# }
# #T_4a15f_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 14.3%, transparent 14.3%);
# }
# #T_4a15f_row6_col0, #T_4a15f_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.0%, transparent 0.0%);
# }
# </style>
# <table id="T_4a15f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a15f_level0_col0" class="col_heading level0 col0" >qualifiedUse</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a15f_level0_row0" class="row_heading level0 row0" >SYMBOL_KIND_METHOD > SYMBOL_USE_VIRTUAL_INVOCATION</th>
#       <td id="T_4a15f_row0_col0" class="data row0 col0" >24285</td>
#     </tr>
#     <tr>
#       <th id="T_4a15f_level0_row1" class="row_heading level0 row1" >SYMBOL_KIND_METHOD > SYMBOL_USE_INVOCATION</th>
#       <td id="T_4a15f_row1_col0" class="data row1 col0" >23575</td>
#     </tr>
#     <tr>
#       <th id="T_4a15f_level0_row2" class="row_heading level0 row2" >SYMBOL_KIND_TYPE > SYMBOL_USE_TYPE_REFERENCE</th>
#       <td id="T_4a15f_row2_col0" class="data row2 col0" >15704</td>
#     </tr>
#     <tr>
#       <th id="T_4a15f_level0_row3" class="row_heading level0 row3" >SYMBOL_KIND_CONSTRUCTOR > SYMBOL_USE_INVOCATION</th>
#       <td id="T_4a15f_row3_col0" class="data row3 col0" >6116</td>
#     </tr>
#     <tr>
#       <th id="T_4a15f_level0_row4" class="row_heading level0 row4" >SYMBOL_KIND_CLASS > SYMBOL_USE_INSTANTIATION</th>
#       <td id="T_4a15f_row4_col0" class="data row4 col0" >6116</td>
#     </tr>
#     <tr>
#       <th id="T_4a15f_level0_row5" class="row_heading level0 row5" >SYMBOL_KIND_METHOD > SYMBOL_USE_STATIC_INVOCATION</th>
#       <td id="T_4a15f_row5_col0" class="data row5 col0" >3480</td>
#     </tr>
#     <tr>
#       <th id="T_4a15f_level0_row6" class="row_heading level0 row6" >SYMBOL_KIND_CLASS > SYMBOL_USE_INHERITANCE</th>
#       <td id="T_4a15f_row6_col0" class="data row6 col0" >4</td>
#     </tr>
#     <tr>
#       <th id="T_4a15f_level0_row7" class="row_heading level0 row7" >SYMBOL_KIND_METHOD > SYMBOL_USE_OVERRIDING</th>
#       <td id="T_4a15f_row7_col0" class="data row7 col0" >4</td>
#     </tr>
#   </tbody>
# </table>
# In clients
# <style type="text/css">
# #T_1ae6f_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_1ae6f_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 97.6%, transparent 97.6%);
# }
# #T_1ae6f_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 65.3%, transparent 65.3%);
# }
# #T_1ae6f_row3_col0, #T_1ae6f_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 25.4%, transparent 25.4%);
# }
# #T_1ae6f_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 13.2%, transparent 13.2%);
# }
# #T_1ae6f_row6_col0, #T_1ae6f_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.0%, transparent 0.0%);
# }
# </style>
# <table id="T_1ae6f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1ae6f_level0_col0" class="col_heading level0 col0" >qualifiedUse</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ae6f_level0_row0" class="row_heading level0 row0" >SYMBOL_KIND_METHOD > SYMBOL_USE_VIRTUAL_INVOCATION</th>
#       <td id="T_1ae6f_row0_col0" class="data row0 col0" >22777</td>
#     </tr>
#     <tr>
#       <th id="T_1ae6f_level0_row1" class="row_heading level0 row1" >SYMBOL_KIND_METHOD > SYMBOL_USE_INVOCATION</th>
#       <td id="T_1ae6f_row1_col0" class="data row1 col0" >22226</td>
#     </tr>
#     <tr>
#       <th id="T_1ae6f_level0_row2" class="row_heading level0 row2" >SYMBOL_KIND_TYPE > SYMBOL_USE_TYPE_REFERENCE</th>
#       <td id="T_1ae6f_row2_col0" class="data row2 col0" >14864</td>
#     </tr>
#     <tr>
#       <th id="T_1ae6f_level0_row3" class="row_heading level0 row3" >SYMBOL_KIND_CONSTRUCTOR > SYMBOL_USE_INVOCATION</th>
#       <td id="T_1ae6f_row3_col0" class="data row3 col0" >5792</td>
#     </tr>
#     <tr>
#       <th id="T_1ae6f_level0_row4" class="row_heading level0 row4" >SYMBOL_KIND_CLASS > SYMBOL_USE_INSTANTIATION</th>
#       <td id="T_1ae6f_row4_col0" class="data row4 col0" >5792</td>
#     </tr>
#     <tr>
#       <th id="T_1ae6f_level0_row5" class="row_heading level0 row5" >SYMBOL_KIND_METHOD > SYMBOL_USE_STATIC_INVOCATION</th>
#       <td id="T_1ae6f_row5_col0" class="data row5 col0" >2998</td>
#     </tr>
#     <tr>
#       <th id="T_1ae6f_level0_row6" class="row_heading level0 row6" >SYMBOL_KIND_CLASS > SYMBOL_USE_INHERITANCE</th>
#       <td id="T_1ae6f_row6_col0" class="data row6 col0" >2</td>
#     </tr>
#     <tr>
#       <th id="T_1ae6f_level0_row7" class="row_heading level0 row7" >SYMBOL_KIND_METHOD > SYMBOL_USE_OVERRIDING</th>
#       <td id="T_1ae6f_row7_col0" class="data row7 col0" >2</td>
#     </tr>
#   </tbody>
# </table>
# In samples
# <style type="text/css">
# #T_ba175_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_ba175_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 80.5%, transparent 80.5%);
# }
# #T_ba175_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 73.2%, transparent 73.2%);
# }
# #T_ba175_row3_col0, #T_ba175_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 43.9%, transparent 43.9%);
# }
# #T_ba175_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.4%, transparent 2.4%);
# }
# </style>
# <table id="T_ba175">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba175_level0_col0" class="col_heading level0 col0" >qualifiedUse</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba175_level0_row0" class="row_heading level0 row0" >SYMBOL_KIND_TYPE > SYMBOL_USE_TYPE_REFERENCE</th>
#       <td id="T_ba175_row0_col0" class="data row0 col0" >41</td>
#     </tr>
#     <tr>
#       <th id="T_ba175_level0_row1" class="row_heading level0 row1" >SYMBOL_KIND_METHOD > SYMBOL_USE_VIRTUAL_INVOCATION</th>
#       <td id="T_ba175_row1_col0" class="data row1 col0" >33</td>
#     </tr>
#     <tr>
#       <th id="T_ba175_level0_row2" class="row_heading level0 row2" >SYMBOL_KIND_METHOD > SYMBOL_USE_INVOCATION</th>
#       <td id="T_ba175_row2_col0" class="data row2 col0" >30</td>
#     </tr>
#     <tr>
#       <th id="T_ba175_level0_row3" class="row_heading level0 row3" >SYMBOL_KIND_CONSTRUCTOR > SYMBOL_USE_INVOCATION</th>
#       <td id="T_ba175_row3_col0" class="data row3 col0" >18</td>
#     </tr>
#     <tr>
#       <th id="T_ba175_level0_row4" class="row_heading level0 row4" >SYMBOL_KIND_CLASS > SYMBOL_USE_INSTANTIATION</th>
#       <td id="T_ba175_row4_col0" class="data row4 col0" >18</td>
#     </tr>
#     <tr>
#       <th id="T_ba175_level0_row5" class="row_heading level0 row5" >SYMBOL_KIND_METHOD > SYMBOL_USE_STATIC_INVOCATION</th>
#       <td id="T_ba175_row5_col0" class="data row5 col0" >1</td>
#     </tr>
#   </tbody>
# </table>
# In tests
# <style type="text/css">
# #T_4e6b3_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_4e6b3_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 89.4%, transparent 89.4%);
# }
# #T_4e6b3_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 54.2%, transparent 54.2%);
# }
# #T_4e6b3_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 32.6%, transparent 32.6%);
# }
# #T_4e6b3_row4_col0, #T_4e6b3_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 20.7%, transparent 20.7%);
# }
# #T_4e6b3_row6_col0, #T_4e6b3_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.1%, transparent 0.1%);
# }
# </style>
# <table id="T_4e6b3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4e6b3_level0_col0" class="col_heading level0 col0" >qualifiedUse</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e6b3_level0_row0" class="row_heading level0 row0" >SYMBOL_KIND_METHOD > SYMBOL_USE_VIRTUAL_INVOCATION</th>
#       <td id="T_4e6b3_row0_col0" class="data row0 col0" >1475</td>
#     </tr>
#     <tr>
#       <th id="T_4e6b3_level0_row1" class="row_heading level0 row1" >SYMBOL_KIND_METHOD > SYMBOL_USE_INVOCATION</th>
#       <td id="T_4e6b3_row1_col0" class="data row1 col0" >1319</td>
#     </tr>
#     <tr>
#       <th id="T_4e6b3_level0_row2" class="row_heading level0 row2" >SYMBOL_KIND_TYPE > SYMBOL_USE_TYPE_REFERENCE</th>
#       <td id="T_4e6b3_row2_col0" class="data row2 col0" >799</td>
#     </tr>
#     <tr>
#       <th id="T_4e6b3_level0_row3" class="row_heading level0 row3" >SYMBOL_KIND_METHOD > SYMBOL_USE_STATIC_INVOCATION</th>
#       <td id="T_4e6b3_row3_col0" class="data row3 col0" >481</td>
#     </tr>
#     <tr>
#       <th id="T_4e6b3_level0_row4" class="row_heading level0 row4" >SYMBOL_KIND_CONSTRUCTOR > SYMBOL_USE_INVOCATION</th>
#       <td id="T_4e6b3_row4_col0" class="data row4 col0" >306</td>
#     </tr>
#     <tr>
#       <th id="T_4e6b3_level0_row5" class="row_heading level0 row5" >SYMBOL_KIND_CLASS > SYMBOL_USE_INSTANTIATION</th>
#       <td id="T_4e6b3_row5_col0" class="data row5 col0" >306</td>
#     </tr>
#     <tr>
#       <th id="T_4e6b3_level0_row6" class="row_heading level0 row6" >SYMBOL_KIND_CLASS > SYMBOL_USE_INHERITANCE</th>
#       <td id="T_4e6b3_row6_col0" class="data row6 col0" >2</td>
#     </tr>
#     <tr>
#       <th id="T_4e6b3_level0_row7" class="row_heading level0 row7" >SYMBOL_KIND_METHOD > SYMBOL_USE_OVERRIDING</th>
#       <td id="T_4e6b3_row7_col0" class="data row7 col0" >2</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Least covered API Use kind

# %% [markdown]
# ### Debug: is there any interaction found in the SUF that do not exist in the SUM?

# %%
suf_not_seen = unique_uses(suf, sum)
print(len(suf_not_seen))
display(suf_not_seen)
# Out:
# 0
# Empty DataFrame
# Columns: [usageKind, usageType, usageFullyQualifiedName]
# Index: []

# %% [markdown]
# ## SUF comparisons

# %% [markdown]
#     - Funny thing: there are samples using `*.internal.*` types!

# %%
only_client_not_in_test = unique_uses(suf_client, suf_test)
print(f'{len(only_client_not_in_test)} interactions done in clients, not in tests')
display(only_client_not_in_test.head(15))

only_client_not_in_sample = unique_uses(suf_client, suf_sample)
print(f'{len(only_client_not_in_sample)} interactions done in clients, not in samples')
display(only_client_not_in_sample.head(15))

only_sample_not_in_client = unique_uses(suf_sample, suf_client)
print(f'{len(only_sample_not_in_client)} interactions done in samples, not in clients')
display(only_sample_not_in_client.head(15))

only_sample_not_in_test = unique_uses(suf_sample, suf_test)
print(f'{len(only_sample_not_in_test)} interactions done in samples, not in tests')
display(only_sample_not_in_test.head(15))

# Union of interactions that we find in every client 'kind'?
# Out:
# 52 interactions done in clients, not in tests
#                    usageKind                     usageType  \
# 41   SYMBOL_KIND_CONSTRUCTOR         SYMBOL_USE_INVOCATION
# 42         SYMBOL_KIND_CLASS      SYMBOL_USE_INSTANTIATION
# 53        SYMBOL_KIND_METHOD         SYMBOL_USE_INVOCATION
# 57        SYMBOL_KIND_METHOD  SYMBOL_USE_STATIC_INVOCATION
# 73        SYMBOL_KIND_METHOD         SYMBOL_USE_INVOCATION
# 80        SYMBOL_KIND_METHOD         SYMBOL_USE_INVOCATION
# 81        SYMBOL_KIND_METHOD         SYMBOL_USE_INVOCATION
# 82        SYMBOL_KIND_METHOD         SYMBOL_USE_INVOCATION
# 92        SYMBOL_KIND_METHOD         SYMBOL_USE_INVOCATION
# 113        SYMBOL_KIND_CLASS        SYMBOL_USE_INHERITANCE
# 114       SYMBOL_KIND_METHOD         SYMBOL_USE_OVERRIDING
# 115       SYMBOL_KIND_METHOD         SYMBOL_USE_INVOCATION
# 120       SYMBOL_KIND_METHOD         SYMBOL_USE_INVOCATION
# 122         SYMBOL_KIND_TYPE     SYMBOL_USE_TYPE_REFERENCE
# 123       SYMBOL_KIND_METHOD         SYMBOL_USE_INVOCATION
#
#                                                                                                                        usageFullyQualifiedName
# 41                                                                                     org.apache.commons.cli.ParseException(java.lang.String)
# 42                                                                                                       org.apache.commons.cli.ParseException
# 53                                       org.apache.commons.cli.DefaultParser.parse(org.apache.commons.cli.Options,java.lang.String[],boolean)
# 57                                                                                    org.apache.commons.cli.OptionBuilder.isRequired(boolean)
# 73                                                                                       org.apache.commons.cli.Option.setValueSeparator(char)
# 80                                org.apache.commons.cli.Options.addRequiredOption(java.lang.String,java.lang.String,boolean,java.lang.String)
# 81                                     org.apache.commons.cli.HelpFormatter.printHelp(java.lang.String,org.apache.commons.cli.Options,boolean)
# 82                  org.apache.commons.cli.DefaultParser.parse(org.apache.commons.cli.Options,java.lang.String[],java.util.Properties,boolean)
# 92   org.apache.commons.cli.HelpFormatter.printHelp(java.lang.String,java.lang.String,org.apache.commons.cli.Options,java.lang.String,boolean)
# 113                                                                                                           org.apache.commons.cli.GnuParser
# 114                                                       org.apache.commons.cli.Parser.processOption(java.lang.String,java.util.ListIterator)
# 115                                                       org.apache.commons.cli.Parser.processOption(java.lang.String,java.util.ListIterator)
# 120      org.apache.commons.cli.HelpFormatter.printHelp(int,java.lang.String,java.lang.String,org.apache.commons.cli.Options,java.lang.String)
# 122                                                                                                       org.apache.commons.cli.OptionBuilder
# 123          org.apache.commons.cli.HelpFormatter.printHelp(java.lang.String,java.lang.String,org.apache.commons.cli.Options,java.lang.String)
# 228 interactions done in clients, not in samples
#                   usageKind              usageType  \
# 18       SYMBOL_KIND_METHOD  SYMBOL_USE_INVOCATION
# 19       SYMBOL_KIND_METHOD  SYMBOL_USE_INVOCATION
# 20       SYMBOL_KIND_METHOD  SYMBOL_USE_INVOCATION
# 21  SYMBOL_KIND_CONSTRUCTOR  SYMBOL_USE_INVOCATION
# 24       SYMBOL_KIND_METHOD  SYMBOL_USE_INVOCATION
# 31       SYMBOL_KIND_METHOD  SYMBOL_USE_INVOCATION
# 32       SYMBOL_KIND_METHOD  SYMBOL_USE_INVOCATION
# 33       SYMBOL_KIND_METHOD  SYMBOL_USE_INVOCATION
# 34       SYMBOL_KIND_METHOD  SYMBOL_USE_INVOCATION
# 35       SYMBOL_KIND_METHOD  SYMBOL_USE_INVOCATION
# 36       SYMBOL_KIND_METHOD  SYMBOL_USE_INVOCATION
# 37       SYMBOL_KIND_METHOD  SYMBOL_USE_INVOCATION
# 38       SYMBOL_KIND_METHOD  SYMBOL_USE_INVOCATION
# 39       SYMBOL_KIND_METHOD  SYMBOL_USE_INVOCATION
# 40       SYMBOL_KIND_METHOD  SYMBOL_USE_INVOCATION
#
#                                                                           usageFullyQualifiedName
# 18                                                org.apache.commons.cli.CommandLine.getOptions()
# 19                                                         org.apache.commons.cli.Option.getOpt()
# 20                                       org.apache.commons.cli.Option.getValue(java.lang.String)
# 21                       org.apache.commons.cli.Option(java.lang.String,boolean,java.lang.String)
# 24           org.apache.commons.cli.CommandLine.getOptionValue(java.lang.String,java.lang.String)
# 31                                                   org.apache.commons.cli.CommandLine.getArgs()
# 32                                org.apache.commons.cli.Option$Builder.argName(java.lang.String)
# 33                                          org.apache.commons.cli.Option$Builder.hasArg(boolean)
# 34                                        org.apache.commons.cli.Option$Builder.required(boolean)
# 35                      org.apache.commons.cli.CommandLine.getParsedOptionValue(java.lang.String)
# 36                           org.apache.commons.cli.CommandLine.getOptionValues(java.lang.String)
# 37                                    org.apache.commons.cli.Option$Builder.type(java.lang.Class)
# 38                                     org.apache.commons.cli.Option$Builder.optionalArg(boolean)
# 39                                        org.apache.commons.cli.Option$Builder.numberOfArgs(int)
# 40  org.apache.commons.cli.DefaultParser.parse(org.apache.commons.cli.Options,java.lang.String[])
# 0 interactions done in samples, not in clients
# Empty DataFrame
# Columns: [usageKind, usageType, usageFullyQualifiedName]
# Index: []
# 0 interactions done in samples, not in tests
# Empty DataFrame
# Columns: [usageKind, usageType, usageFullyQualifiedName]
# Index: []
